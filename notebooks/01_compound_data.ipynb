# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/jakubsmekal/miniconda3/envs/algo_jupyter/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jakubsmekal/miniconda3/envs/algo_jupyter/lib/python3.9/site-packages (from matplotlib) (4.28.4)
# Requirement already satisfied: numpy>=1.17 in /Users/jakubsmekal/miniconda3/envs/algo_jupyter/lib/python3.9/site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: packaging>=20.0 in /Users/jakubsmekal/miniconda3/envs/algo_jupyter/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jakubsmekal/miniconda3/envs/algo_jupyter/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/jakubsmekal/miniconda3/envs/algo_jupyter/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jakubsmekal/miniconda3/envs/algo_jupyter/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/jakubsmekal/miniconda3/envs/algo_jupyter/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jakubsmekal/miniconda3/envs/algo_jupyter/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: six>=1.5 in /Users/jakubsmekal/miniconda3/envs/algo_jupyter/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
pd.read_csv('Compound_-_Data_1.csv')
# Out:
#         Timestamp Token  Borrowing Rate  Deposit Rate  Borrow Volume  \
# 0      1609471800   DAI        0.073195      0.050982   1.069964e+09
# 1      1609471800  USDC        0.087046      0.066993   7.285430e+08
# 2      1609471800  USDT        0.099588      0.077548   6.430536e+07
# 3      1609471800   ETH        0.022952      0.000489   3.055365e+04
# 4      1609473600   DAI        0.073101      0.050912   1.069961e+09
# ...           ...   ...             ...           ...            ...
# 66789  1639539000   ETH        0.027215      0.000761   5.316478e+04
# 66790  1639540800   ETH        0.027214      0.000761   5.316480e+04
# 66791  1639542600   ETH        0.027214      0.000761   5.316488e+04
# 66792  1639544400   ETH        0.027226      0.000764   5.316501e+04
# 66793  1639546200   ETH        0.027229      0.000764   5.316508e+04
#
#        Supply Volume
# 0       6.196481e+10
# 1       4.063042e+10
# 2       3.696225e+09
# 3       5.663257e+07
# 4       6.197050e+10
# ...              ...
# 66789   7.481990e+07
# 66790   7.482188e+07
# 66791   7.482482e+07
# 66792   7.461519e+07
# 66793   7.456406e+07
#
# [66794 rows x 6 columns]

# %%
df = pd.read_csv('Compound_-_Data_1.csv')

# %%
ys = pd.DataFrame(df, columns=['Token', 'Borrowing Rate'])
ys_eth = ys[ys['Token'] == 'ETH']
ys_dai = ys[ys['Token'] == 'DAI']
ys_usdc = ys[ys['Token'] == 'USDC']
ys_usdt = ys[ys['Token'] == 'USDT']

# %%
xs = pd.DataFrame(df, columns=['Token', 'Deposit Rate', 'Borrow Volume', 'Supply Volume'])
xs_eth = xs[xs['Token'] == 'ETH']
xs_dai = xs[xs['Token'] == 'DAI']
xs_usdc = xs[xs['Token'] == 'USDC']
xs_usdt = xs[xs['Token'] == 'USDT']

# %%
print(ys_dai)
# Out:
#       Token  Borrowing Rate
# 0       DAI        0.073195
# 4       DAI        0.073101
# 8       DAI        0.073061
# 12      DAI        0.073436
# 16      DAI        0.067829
# ...     ...             ...
# 66732   DAI        0.046638
# 66737   DAI        0.046120
# 66740   DAI        0.046639
# 66744   DAI        0.046691
# 66749   DAI        0.047191
#
# [16688 rows x 2 columns]

# %%
plt.plot(ys_usdt['Borrowing Rate'])

# %%
plt.plot(xs_eth['Supply Volume'])

# %%
plt.plot(xs_eth['Deposit Rate'])

# %%
plt.plot(xs_eth['Borrow Volume'])

# %%
aave = pd.read_csv('aave_v2_borrow.csv')

# %%
print(aave['symbol'])
# Out:
#        symbol                       date protocol  avg_stable_borrow_rate  \
# 0        USDC  2021-12-15T17:04:10+00:00  aave_v2                     NaN
# 1         DAI  2021-12-15T16:55:56+00:00  aave_v2                     NaN
# 2        USDC  2021-12-15T16:54:39+00:00  aave_v2                     NaN
# 3        USDT  2021-12-15T16:52:05+00:00  aave_v2                     NaN
# 4        USDC  2021-12-15T16:44:00+00:00  aave_v2                     NaN
# ...       ...                        ...      ...                     ...
# 100564   USDC  2020-12-02T15:04:19+00:00  aave_v2                     NaN
# 100565    DAI  2020-12-02T14:57:43+00:00  aave_v2                     NaN
# 100566    DAI  2020-12-02T13:10:19+00:00  aave_v2                     NaN
# 100567    DAI  2020-12-02T09:34:18+00:00  aave_v2                     NaN
# 100568    DAI  2020-12-01T16:46:58+00:00  aave_v2                     NaN
#
#         avg_variable_borrow_rate
# 0                       3.651738
# 1                       3.844345
# 2                       3.635794
# 3                       3.458650
# 4                       3.623783
# ...                          ...
# 100564                  1.591810
# 100565                  0.075189
# 100566                  0.141511
# 100567                  2.500015
# 100568                  1.250000
#
# [100569 rows x 5 columns]

# %%
ys = pd.DataFrame(aave, columns=['symbol', 'avg_variable_borrow_rate'])
ys_eth = ys[ys['symbol'] == 'WETH']
ys_dai = ys[ys['symbol'] == 'DAI']
ys_usdc = ys[ys['symbol'] == 'USDC']
ys_usdt = ys[ys['symbol'] == 'USDT']

# %%
xs = pd.DataFrame(aave, columns=['symbol', 'avg_variable_borrow_rate'])
xs_eth = xs[xs['symbol'] == 'WETH']
xs_dai = xs[xs['symbol'] == 'DAI']
xs_usdc = xs[xs['symbol'] == 'USDC']
xs_usdt = xs[xs['symbol'] == 'USDT']

# %%
print(ys_eth)
# Out:
#        symbol  avg_variable_borrow_rate
# 5        WETH                  0.313114
# 13       WETH                  0.313457
# 19       WETH                  0.280901
# 20       WETH                  0.280447
# 21       WETH                  0.280634
# ...       ...                       ...
# 100499   WETH                       NaN
# 100554   WETH                  0.332631
# 100556   WETH                  0.332833
# 100561   WETH                  1.933514
# 100562   WETH                  0.175774
#
# [9384 rows x 2 columns]

# %%
plt.plot(ys_eth['avg_variable_borrow_rate'])

# %%
plt.plot(xs_eth['avg_variable_borrow_rate'])
